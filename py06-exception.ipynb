# %% [markdown]
# #### 예외
#
# 문법적으로 문제가 없는 코드를 실행 중에 더 이상 진행 불가한 사항
#
#
#  예외 상황<br>
#    0으로 숫자 나누기<br>
#    문자열과 숫자 더하기<br>
#    참조 범위를 넘어서 인덱스 참조하기<br>
#    등록되어 있지 않은 키로 사전 검색하기 <br>

# %%
a =10 / 0
