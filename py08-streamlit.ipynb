# %% [markdown]
# # Streamlit이란?
# * https://streamlit.io
# <br>
# Python 기반 오픈소스 웹 애플리케이션 프레임워크로, 데이터 사이언스, 머신러닝, 데이터 분석 결과 등을 쉽고 빠르게 웹 앱 형태로 시각화하고 배포할 수 있도록 설계된 도구. 복잡한 웹 개발 지식 없이도 파이썬 코드만으로 대화형 웹 애플리케이션을 만들 수 있다는 점이 강점

# %% [markdown]
# 그럼 노션도 이걸로 커스터마이징 가능함?

# %% [markdown]
# | 주요 특징 | 활용 예시 |
# |---|---|
# | 파이썬 코드만으로 웹 앱 개발 가능 | 데이터 분석 대시보드 제작 |
# | 대화형 위젯(버튼, 슬라이더 등) 제공 | 머신러닝 모델 시연 및 결과 시각화 |
# | 빠른 개발 및 배포 지원 | 인터랙티브 데이터 탐색 도구 구현 |
# | 데이터 시각화 및 분석에 최적화 | 챗봇 및 대화형 AI 웹앱 개발 |
# | 오픈소스, 무료 사용 가능 | 실시간 데이터 모니터링 및 리포트 제공 |
# | 별도의 웹 기술(HTML, JS) 불필요 | 사용자 맞춤형 입력 폼 및 데이터 수집 도구 제작 |

# %% [markdown]
# # 1. packages Installation

# %%
# uv pip install streamlit numpy pandas matplotlib
# !uv add streamlit numpy pandas matplotlib
# Out:
# Resolved 51 packages in 1.02s
# Downloading fonttools (2.2MiB)
# Downloading streamlit (9.9MiB)
# Downloading pydeck (10.9MiB)
# Downloading matplotlib (8.9MiB)
# Downloading pillow (6.9MiB)
# Downloading pyarrow (26.1MiB)
#  Downloaded fonttools
#  Downloaded pillow
#  Downloaded matplotlib
#  Downloaded pydeck
#  Downloaded streamlit
#  Downloaded pyarrow
# Prepared 42 packages in 3.58s
# Installed 42 packages in 493ms
#  + altair==6.2.2
#  + anyio==4.14.2
#  + attrs==26.1.0
#  + blinker==1.9.0
#  + cachetools==7.1.4
#  + certifi==2026.6.17
#  + charset-normalizer==3.4.9
#  + click==8.4.2
#  + contourpy==1.3.3
#  + cycler==0.12.1
#  + fonttools==4.63.0
#  + gitdb==4.0.12
#  + gitpython==3.1.51
#  + h11==0.16.0
#  + httptools==0.8.0
#  + idna==3.18
#  + itsdangerous==2.2.0
#  + jinja2==3.1.6
#  + jsonschema==4.26.0
#  + jsonschema-specifications==2025.9.1
#  + kiwisolver==1.5.0
#  + markupsafe==3.0.3
#  + matplotlib==3.11.0
#  + narwhals==2.24.0
#  + pillow==12.3.0
#  + protobuf==7.35.1
#  + pyarrow==24.0.0
#  + pydeck==0.9.3
#  + pyparsing==3.3.2
#  + python-multipart==0.0.32
#  + referencing==0.37.0
#  + requests==2.34.2
#  + rpds-py==2026.6.3
#  + smmap==5.0.3
#  + starlette==1.3.1
#  + streamlit==1.59.2
#  + tenacity==9.1.4
#  + toml==0.10.2
#  + urllib3==2.7.0
#  + uvicorn==0.51.0
#  + watchdog==6.0.0
#  + websockets==16.1

# %% [markdown]
# 2. Streamlit - Textsm

# %% [markdown]
# 1) app.py 작성

# %%
# %%writefile app.py

import streamlit as st # 확장자가 길어서 st 로 줄임

# 앱의 메인 타이틀을 출력
st.title('튜토리얼1 : 텍스트 출력')


# 큰 제목을 출력
st.header(" 기본 텍스트 출력")

# 일반적인 문자열을 그대로 출력
st.text('기본 텍스트를 출력합니다.')

# 중간 제목을 출력
st.subheader("마크다운 활용")

# 마크다운 문법을 활용하여 서식을 적용한 텍스트를 출력
st.markdown("**굵게**,_기울임_, [링크](https://streamlit.io)")

# # 코드 설명 섹션을 출력
# st.subheader("코드 출력")
# 
#  # 코드 블록을 출력(하이라이팅 포함)
# st.code("print('Hello, Streamlit!)", language="python")

st.divider # 뭐야 뭐가 움직여

# 코드 설명 섹션을 출력
st.subheader("코드 출력")

# 코드 블록을 출력 (하이라이팅 포함)
st.code("print('Hello, Streamlit!')", language="python")

st.divider
# Out:
# Overwriting app.py

# %% [markdown]
# 이거 귀찮은데 걍 노션으로 만들고 변환하게 하는건 못하나?

# %% [markdown]
# 2) Terminal 에서 Streamlit 실행
#
# **streamlit run app.py**

# %% [markdown]
# # 2.Streamlit - Inputs
#
# >### 1) app.py 수정
# * 실행 후 브라우저에서 <font color=red>Refresh</font> 클릭   >>>이거 <span color=green>이것도가능한거같은데<span>

# %%
# %%writefile app.py

import streamlit as st

# 사용자 입력 관련 기능 소개
st.title('튜토리얼 2 : 입력 위젯')

#문자열을 입력받을 수 있는 텍스트 필드 생성
name =st.text_input('이름을 입력하세요')

# 숫자를 입력받는 위젯 - 최소/최대값 범위 지정
age = st.number_input("나이를 입력하세요", min_value=0, max_value=120)

# 드롭다운 형태로 항목 선택
hobby = st.selectbox("취미를 선택하세요", ["독서","운동","게임","요리"])

# 체크박스 - True/False 값 반환
agree = st.checkbox("개인정보 수집에 동의합니다.")

if name and agree:
    st.success(f'{name}님,{age}세 / 취미:{hobby}')
# Out:
# Overwriting app.py

# %% [markdown]
# # 3 Streamlit - Button

# %% [markdown]
# >### 1) app.py 수정
# * 실행 후 브라우저에서 <font color=red>Refresh</font> 클릭   >>>이거 <span color=green>이것도가능한거같은데<span>

# %%
# %%writefile app.py



import streamlit as st


# 버튼 및 조건부 로직 소개
st.title("튜토리얼 3: 버튼과 조건 처리")




# 버튼을 클릭하면 True를 반환
if st.button("누르세요"):
    # 애니메이션 효과를 표시
    st.balloons()
    # 버튼 클릭 메시지 출력
    st.write("버튼이 눌렸습니다!")


st.divider()


st.header("st.button", divider="rainbow")


if st.button("Reset", type="primary"):
    st.write("Reset is pushed")
   
if st.button("Say hello"):
    st.write("Hello there!! :smile:")
else:
    st.write("Goodbye")




st.divider()
st.button("Button",key=1) #기본값
 
st.button("Button",key=2,use_container_width = True) #부모의 너비
 
st.button("Button",key=3,use_container_width = False) #기본값
 
st.button("Button",key=4,disabled = True) #비활성
 
st.button("Button",key=5,disabled = False) #활성
 
st.button("Button",key=6,type = "secondary") #기본값

st.button("Button",key=7,type = "primary") #추가 강조


st.divider()
def handle_on_click():
    st.balloons()
    print("clicked on_click button")
def handle_on_click_args(*args):
    st.snow()
    print(f"clicked on_click args button with args={args}")
def handle_on_click_kwargs(**kwargs):
    st.snow()
    print(f"clicked on_click kwargs button with kwargs={kwargs}")
   
st.button("on_click", on_click=handle_on_click)
st.button("on_click args", on_click=handle_on_click_args, args=("123",))
st.button("on_click kwargs", on_click=handle_on_click_kwargs, kwargs={"one":1})
# Out:
# Overwriting app.py

# %% [markdown]
# # 3. Streamlit - File Upload

# %% [markdown]
# >### 1) app.py 수정
# * 실행 후 브라우저에서 <font color=red>Refresh</font> 클릭   >>>이거 <span color=green>이것도가능한거같은데<span>

# %%
# %%writefile app.py


import streamlit as st
import pandas as pd


# 파일 업로드 기능 소개
st.title("📂 튜토리얼 4: 파일 업로드")




# 사용자가 파일을 업로드할 수 있는 위젯 (CSV만 허용)
uploaded_file = st.file_uploader("CSV 파일 업로드", type=["csv"])




if uploaded_file:
    # 업로드된 파일을 Pandas 데이터프레임으로 읽기
    df = pd.read_csv(uploaded_file)
    # 데이터프레임 상위 5개 행을 출력
    st.dataframe(df.head())

# accept_multiple_files=True > 여러개의 이미지 업로드 가능
uploaded_files = st.file_uploader("파일을 선택해주세요", accept_multiple_files=True,
type=["png","jpg","jpeg","gif"])
for uploaded_file in uploaded_files:
    bytes_data = uploaded_file.read()
    # st.write(bytes_data)
    st.image(uploaded_file, caption=uploaded_file.name, use_container_width=True)
# Out:
# Overwriting app.py

# %% [markdown]
# ### 기능 제외상태, 해당 내역에 대해 갱신 필요
#
#
# st.divider()
# st.title("Download data")
#
#
# st.header("Download as csv",divider="rainbow")
# csv = pd.read_csv("./source/jumsu.csv").to_csv()
#
#
# st.download_button(
#     label="Download data as CSV",
#     data=csv,
#     file_name="./source/jumsu.csv",
#     mime="text/csv",
# )
#
#
# with open("source/git_ta.jpg","rb")as file: #위치 지정 중요함
#     btn = st.download_button(
#     label="이미지 다운로드",
#     data=file,
#     file_name="source/git_ta.jpg",
#     mine="image/jpg"

# %% [markdown]
# >### 4)
# * 실행 후 브라우저에서 <font color=red>Refresh</font> 클릭   >>>이거 <span color=green>이것도가능한거같은데<span>

# %%
# !uv add seaborn
# Out:
# Resolved 52 packages in 280ms
# Prepared 1 package in 88ms
# Installed 1 package in 101ms
#  + seaborn==0.13.2

# %%
# %%writefile app.py


import streamlit as st
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns


# 차트 시각화 소개
st.title("📊 튜토리얼 5: 차트 시각화")




# 예시용 숫자 데이터 생성
data = pd.DataFrame({
    "x": [1,2,3,4,5],
    "y": [-0.5, 1, -1, 2 , 0]
})




# matplotlib로 선 그래프를 생성
fig, ax = plt.subplots()
ax.plot(data["x"], data["y"], marker='o')


# Streamlit 차트 렌더링
st.pyplot(fig)

#np.random.randn(10, 2 : 정규분포를 따르는 난수를 10행 2열로 구함
chart_data = pd.DataFrame(np.random.randn(10, 2), columns=["s","t"])
st.line_chart(chart_data, width=0, height=300, use_container_width=True)


data = {"Year": [2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023],
        "Sales": [100, 150, 200, 180, 150, 130, 200, 250, 270],
        "Revenue": [50, 80, 120, 90, 100, 80, 150, 200, 220]}
df = pd.DataFrame(data)
sns.set_palette("Set2")             # 그래프의 기본 색상 테마를 'set2'로 설정
fig = plt.figure(figsize=(10, 6))   # 다중라인 그래프 그리기
 
plt.title("Sales and Revenue Trend")
plt.xlabel("Year")
plt.ylabel("Amount")
 
sns.lineplot(x="Year", y="Sales", data=df, marker="o", label="Sales")
sns.lineplot(x="Year", y="Revenue", data=df, marker="o", label="Revenue")
plt.legend(loc ="upper right")      # 범례
st.pyplot(fig)



labels = ["A", "B", "C", "D"]
sizes = [random.randint(1, 100) for _ in range(len(labels))]


#그래프
fig, ax = plt.subplots()
ax.pie(sizes, labels=["A", "B", "C", "D"] ,
 colors= ["lightsteelblue", "thistle", "bisque", "lightsalmon"],  
  autopct="%1.1f%%",                                            # 소수점 표현  
  explode=[0 if s != min(sizes) else 0.1 for s in sizes])       # 차트 내 최소값이 그래프에서돌출되어 보이게


st.pyplot(fig)
# Out:
# Overwriting app.py

# %% [markdown]
# >### 4) 사이드바
# * 실행 후 브라우저에서 <font color=red>Refresh</font> 클릭   >>>이거 <span color=green>이것도가능한거같은데<span>

# %%
# %%writefile app.py


import streamlit as st


# 사이드바와 조건부 표시 UI 소개
st.title("📑 튜토리얼 5: 사이드바와 토글")




# 사이드바에 타이틀 출력
st.sidebar.title("사이드바 메뉴")




# 사이드바에 라디오 버튼으로 메뉴 선택 기능 추가
menu = st.sidebar.radio("메뉴 선택", ["홈", "정보", "설정"])




# 선택된 메뉴를 출력
st.sidebar.write("선택한 메뉴:", menu)




# 토글 스위치를 통해 조건 제어
show = st.toggle("자세히 보기")




# 토글이 활성화되면 정보 메시지 출력
if show:
    st.info("여기에 자세한 내용이 표시됩니다.")
# Out:
# Overwriting app.py
