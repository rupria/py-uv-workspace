# %%
# 함수(function)
# - 함수: 특정 목적을 가진 코드의 집합이며 독립적으로 호출될 수 있는 기능이다.
# - 함수 구조
#  ```
#    def 함수이름(parameter_1, parameter_2) : # 파라미터 유무는 차이 있음.
#        수행할 문장
#        return 결과값 # 리턴값도 없을 수 있음.
#  ```
# - 함수 호출
#  ```
#     함수이름(argument_1, argument_2 )
#  ```
#   parameter : 인자, argument : 인수
#

# %%
# 함수를 정의할 때 수행할 문장을 구현하지 않으면 에러가 발생한다.
def proc():
  pass  # pass는 구현을 안할때 오류가 발생하지 않도록 사용한다. 협업 시 기능 관련해서 각자 구분해서 할 때, 우선순위가 낮아서 후순위 작업일 때?

# %%
print(proc()) # 함수 실행결과를 리턴한다. 만약 print 없이 실행하면 None 도 없이 빈 값을 출력합니다.
# Out:
# None

# %%
print(proc) # 함수식이 나옵니다. 무선 키보드를 살까 고민중입니다.
# Out:
# <function proc at 0x000001F4B0305800>

# %%
a = proc
print(type(a))
print(a())
# Out:
# <class 'function'>
# None
